# %% [markdown]
# # Tech Field Day CLUS 2017
# # APIs have arrived to network devices: With models

# %% [markdown]
# # Table of Contents
# <div class="lev1 toc-item"><a href="#Jupyter-Notebooks" data-toc-modified-id="Jupyter-Notebooks-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Jupyter Notebooks</a></div>
# <div class="lev1 toc-item"><a href="#Operational-Data-via-CLI-Automation" data-toc-modified-id="Operational-Data-via-CLI-Automation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Operational Data via CLI Automation</a></div>
# <div class="lev1 toc-item"><a href="#NETCONF/YANG" data-toc-modified-id="NETCONF/YANG-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>NETCONF/YANG</a></div>
# <div class="lev2 toc-item"><a href="#NETCONF-Routing-Table" data-toc-modified-id="NETCONF-Routing-Table-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>NETCONF Routing Table</a></div>
#
# <div class="lev2 toc-item"><a href="#YANG-Models" data-toc-modified-id="YANG-Models-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>YANG Models</a></div>
#
# <div class="lev2 toc-item"><a href="#NETCONF-Operational-Data" data-toc-modified-id="NETCONF-Operational-Data-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>NETCONF Operational Data</a></div>
#
# <div class="lev2 toc-item"><a href="#NETCONF-Configuration-Data" data-toc-modified-id="NETCONF-Configuration-Data-33"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>NETCONF Configuration Data</a></div>
#
# <div class="lev1 toc-item"><a href="#RESTCONF" data-toc-modified-id="RESTCONF-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>RESTCONF</a></div>
# <div class="lev1 toc-item"><a href="#YDK" data-toc-modified-id="YDK-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>YDK</a></div>
#
# <div class="lev1 toc-item"><a href="#Telemetry" data-toc-modified-id="Telemetry-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Telemetry</a></div>

# %% [markdown]
# # Jupyter Notebooks
# The *Jupyter Notebooks* in this workbench class are interactive learning environments. We are using them to learn about network device programability in combination with virtual Cisco network devices.
#
# Notebooks are **interactive**, the code and text in each notebook can be changed on the fly and the result of those changes can be seen immediately within the notebook itself.
#
# Notebooks are organized in *cells*, each displayed *rectangle* or *cell* is basically either Markdown text (like this cell) or Python code. Python code can be *executed* by either clicking the  <span class="inline">![](images/forwardicon.png)</span> in the 'Cell' menu in the menu bar or the key combination 'Shift-Enter'.
#
# <div class="my-notify-warning">
#
# <p>**IMPORTANT for Execution. PLEASE READ**. At its simplest, this is a playbook and execution is top-down. Code cells will look something like `In [#]:` (with '#' being a number). That's where you want to single-click. To execute the code, simply hit Shift+Enter.</p>
#
# <p>The code should execute, and move onto the next cell. The number in `In [#]:` will change and if there is some return value (as opposed to an explicit `print()` statement) it will appear in an `Out [#]:` cell. The numbers will change after each cell execution.</p>
#
# <p>It's easy to "execute" an entire notebook, task-by-task, by continuing to execute Shift+Return. Also, if you ever see `In [*]:` in your code cells (note the asterisk '\*'), it just means things are executing, and you are probably waiting on data to come back.</p>
#
# <p>So depending on what you're doing, some patience might be required.</p>
#
# </div>

# %% [markdown]
# # Operational Data via CLI Automation
# Here we will set variables that we will use thoughout the session

# %%
HOST = '127.0.0.1'
PORT_SSH = 2222
PORT_NC = 2223
USER = 'vagrant'
PASS = 'vagrant'

# %%
HOST = 'o22-3850-4'
PORT_SSH = 22
PORT_NC = 830
USER = 'cisco'
PASS = 'C1sdevops'

# %%
HOST = '172.27.255.13'
PORT_SSH = 22
PORT_NC = 830
USER = 'cisco'
PASS = 'cisco'

# %% [markdown]
# Programmability has been around for a long time over the CLI API.  We all use it for FDN, but there are capabilities added over the years to communicate with devices via Python over ssh leveraging some form of python expect.  In this case we will use a tool called Netmiko.  However the format of the data is meant for human consumption, not a machine interface.

# %%
import jtextfsm as textfsm
from netmiko import ConnectHandler
import pprint

def get_show_inventory(ip, port, username, password):
    # establish a connection to the device
    ssh_connection = ConnectHandler(
        device_type='cisco_ios',
        ip=ip,
        port=port,
        username=username,
        password=password)
    # enter enable mode
    ssh_connection.enable()
    # prepend the command prompt to the result (used to identify the local device)
    result = ssh_connection.find_prompt() + "\n"
    # execute the show inventory command with extended delay
    result += ssh_connection.send_command("show inventory", delay_factor=2)
    # close SSH connection
    ssh_connection.disconnect()
    return result

# %% [markdown]
# If we are lucky there is some clear format of the response that we can leverage regular expression filters to turn the response into programming data types

# %%
    raw_text_data = get_show_inventory(HOST, PORT_SSH, USER, PASS)
    print ('This is what the text looks like\n' + raw_text_data)
    # Run the text through the FSM. 
    # The argument 'template' is a file handle and 'raw_text_data' is a 
    # string with the content from the show_inventory.txt file
    template = open("cisco_ios_show_inventory.template")
    re_table = textfsm.TextFSM(template)
    fsm_results = re_table.ParseText(raw_text_data)
    # build keys for inventory sub-items 
    keys = [s for s in re_table.header]
    #build inventory list of dictionaries
    inventory = []
    for row in fsm_results:
      entry = {}
      for i, item in enumerate(row):
        entry.update({keys[i]:item})
      inventory.append(entry)
    pp = pprint.PrettyPrinter(indent=2)
# Out:
# This is what the text looks like
# ddmi-asr1006-2#
# NAME: "Chassis", DESCR: "Cisco ASR1006 Chassis"
# PID: ASR1006           , VID: V01  , SN: FOX1224G4XC
#
# NAME: "module 1", DESCR: "Cisco ASR1000 SPA Interface Processor 10"
# PID: ASR1000-SIP10     , VID: V03  , SN: JAE1221IZP4
#
# NAME: "module R1", DESCR: "Cisco ASR1000 Route Processor 2"
# PID: ASR1000-RP2       , VID: V03  , SN: JAE17040BBY
#
# NAME: "module F0", DESCR: "Cisco ASR1000 Embedded Services Processor, 10Gbps"
# PID: ASR1000-ESP10     , VID: V03  , SN: JAE1227NTTB
#
# NAME: "module F1", DESCR: "Cisco ASR1000 Embedded Services Processor, 10Gbps"
# PID: ASR1000-ESP10     , VID: V03  , SN: JAE1229P5QK
#
# NAME: "Power Supply Module 0", DESCR: "Cisco ASR1006 AC Power Supply"
# PID: ASR1006-PWR-AC    , VID: V01  , SN: ART1227Q00L
#
# NAME: "Power Supply Module 1", DESCR: "Cisco ASR1006 AC Power Supply"
# PID: ASR1006-PWR-AC    , VID: V01  , SN: ART1227Q00P

# %% [markdown]
# Here we can see what the template looks like

# %%
    print(template.read())

# %% [markdown]
# Now that we have srtuctured data, lets do something interesting with it.  We can choose how we display it or to even search for a value of interest.

# %%
    print('Results translated through regular expression template organized as a dictionary')
    pp.pprint(inventory) # Print full inventory as dictionary
    print([key for key, value in inventory[0].items()])  # print key values as list
    for item in inventory:   # print inventory elements a table 
        print([item[key] for key in item])
# Out:
# Results translated through regular expression template organized as a dictionary
# [ { u'DESCR': u'Cisco ASR1006 Chassis',
#     u'NAME': u'Chassis',
#     u'PID': u'ASR1006',
#     u'SN': u'FOX1224G4XC',
#     u'VID': u'V01  '},
#   { u'DESCR': u'Cisco ASR1000 SPA Interface Processor 10',
#     u'NAME': u'module 1',
#     u'PID': u'ASR1000-SIP10',
#     u'SN': u'JAE1221IZP4',
#     u'VID': u'V03  '},
#   { u'DESCR': u'Cisco ASR1000 Route Processor 2',
#     u'NAME': u'module R1',
#     u'PID': u'ASR1000-RP2',
#     u'SN': u'JAE17040BBY',
#     u'VID': u'V03  '},
#   { u'DESCR': u'Cisco ASR1000 Embedded Services Processor, 10Gbps',
#     u'NAME': u'module F0',
#     u'PID': u'ASR1000-ESP10',
#     u'SN': u'JAE1227NTTB',
#     u'VID': u'V03  '},
#   { u'DESCR': u'Cisco ASR1000 Embedded Services Processor, 10Gbps',
#     u'NAME': u'module F1',
#     u'PID': u'ASR1000-ESP10',
#     u'SN': u'JAE1229P5QK',
#     u'VID': u'V03  '},
#   { u'DESCR': u'Cisco ASR1006 AC Power Supply',
#     u'NAME': u'Power Supply Module 0',
#     u'PID': u'ASR1006-PWR-AC',
#     u'SN': u'ART1227Q00L',
#     u'VID': u'V01  '},
#   { u'DESCR': u'Cisco ASR1006 AC Power Supply',
#     u'NAME': u'Power Supply Module 1',
#     u'PID': u'ASR1006-PWR-AC',
#     u'SN': u'ART1227Q00P',
#     u'VID': u'V01  '}]
# [u'VID', u'PID', u'NAME', u'DESCR', u'SN']
# [u'V01  ', u'ASR1006', u'Chassis', u'Cisco ASR1006 Chassis', u'FOX1224G4XC']
# [u'V03  ', u'ASR1000-SIP10', u'module 1', u'Cisco ASR1000 SPA Interface Processor 10', u'JAE1221IZP4']
# [u'V03  ', u'ASR1000-RP2', u'module R1', u'Cisco ASR1000 Route Processor 2', u'JAE17040BBY']
# [u'V03  ', u'ASR1000-ESP10', u'module F0', u'Cisco ASR1000 Embedded Services Processor, 10Gbps', u'JAE1227NTTB']
# [u'V03  ', u'ASR1000-ESP10', u'module F1', u'Cisco ASR1000 Embedded Services Processor, 10Gbps', u'JAE1229P5QK']
# [u'V01  ', u'ASR1006-PWR-AC', u'Power Supply Module 0', u'Cisco ASR1006 AC Power Supply', u'ART1227Q00L']
# [u'V01  ', u'ASR1006-PWR-AC', u'Power Supply Module 1', u'Cisco ASR1006 AC Power Supply', u'ART1227Q00P']

# %%
    sought_serial_num = 'JAB1303001C'
    resultlist = [d for d in inventory if d.get('SN', '') == sought_serial_num]
    print('\nFound Devices with specific serial number:' + sought_serial_num)
    pp.pprint(resultlist)

# %% [markdown]
# However, we are not always so lucky to have data that we can easily parse.

# %%
def get_show_ip_route(ip, port, username, password):
    # establish a connection to the device
    ssh_connection = ConnectHandler(
        device_type='cisco_ios',
        ip=ip,
        port=port,
        username=username,
        password=password)
    # enter enable mode
    ssh_connection.enable()
    # prepend the command prompt to the result (used to identify the local device)
    result = ssh_connection.find_prompt() + "\n"
    # execute the show inventory command with extended delay
    result += ssh_connection.send_command("show ip route", delay_factor=2)
    # close SSH connection
    ssh_connection.disconnect()
    return result

# %%
raw_text_data = get_show_ip_route(HOST, PORT_SSH, USER, PASS)
print ('This is what the text looks like\n' + raw_text_data)
# Out:
# This is what the text looks like
# ddmi-asr1006-2#
# Codes: L - local, C - connected, S - static, R - RIP, M - mobile, B - BGP
#        D - EIGRP, EX - EIGRP external, O - OSPF, IA - OSPF inter area
#        N1 - OSPF NSSA external type 1, N2 - OSPF NSSA external type 2
#        E1 - OSPF external type 1, E2 - OSPF external type 2
#        i - IS-IS, su - IS-IS summary, L1 - IS-IS level-1, L2 - IS-IS level-2
#        ia - IS-IS inter area, * - candidate default, U - per-user static route
#        o - ODR, P - periodic downloaded static route, H - NHRP, l - LISP
#        a - application route
#        + - replicated route, % - next hop override, p - overrides from PfR
#
# Gateway of last resort is not set
#
#       1.0.0.0/32 is subnetted, 1 subnets
# C        1.2.3.4 is directly connected, Loopback0
# S     192.168.1.0/24 is directly connected, Loopback0

# %% [markdown]
# This text can, of course, be parsed. And has been, many times over the years as part of FDN. But it is complex, fragile and high maintenance under incremental feature updates.

# %% [markdown]
# # NETCONF/YANG
# So let's take a look at an aternative method of interacting with devices.  Let's consider the machine's needs and leverage a model built for it.  That brings us to NETCONF.  Let's try to grab the routing table via programmatic API

# %% [markdown]
# ## NETCONF Operational Data

# %%
import ncclient.manager
from ncclient.operations import TimeoutExpiredError
import pprint
import lxml.etree as etree

m = ncclient.manager.connect(
    host=HOST,
    port=PORT_NC,
    hostkey_verify=False,
    username=USER,
    password=PASS,
    device_params={'name':"csr"})

# %%
rt_filter_oper = '''
  <routing-state xmlns="urn:ietf:params:xml:ns:yang:ietf-routing"/>
  '''
rt_filter_cfg = '''
  <routing xmlns="urn:ietf:params:xml:ns:yang:ietf-routing"/>
  '''
try:
    print ('Here we are printing some routes as XML:\n')
    c = m.get(filter=('subtree', rt_filter_oper))
    # c = m.get_config('running', filter=('subtree', rt_filter))
    # c = m.get_config('running', filter=('xpath', '/routing'))
    # c = m.get(filter=('xpath', '/routing'))
    print(etree.tostring(c.data, pretty_print=True))
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print(e)
    # print("ERORR severity={}, tag={}".format(e.severity, e.tag))
# Out:
# Here we are printing some routes as XML:
#
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0"/>
# No handlers could be found for logger "ncclient.transport.ssh"

# %%
cpu_filter = '''
<filter>
  <cpu-usage xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-process-cpu-oper"/>
</filter>
  '''
try:
    print ('Here we are printing the CPU usage as XML:\n')
    c = m.get(cpu_filter)
    print(etree.tostring(c.data, pretty_print=True))
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("ERORR severity={}, tag={}".format(e.severity, e.tag))
# Out:
# Here we are printing the CPU usage as XML:
#
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <cpu-usage xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-process-cpu-oper">
#     <cpu-utilization>
#       <five-seconds>0</five-seconds>
#       <five-seconds-intr>0</five-seconds-intr>
#       <one-minute>0</one-minute>
#       <five-minutes>0</five-minutes>
#       <cpu-usage-processes>
#         <cpu-usage-process>
#           <pid>1</pid>
#           <name>Chunk Manager</name>
#           <tty>0</tty>
#           <total-run-time>1</total-run-time>
#           <invocation-count>20</invocation-count>
#           <avg-run-time>50</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>2</pid>
#           <name>Load Meter</name>
#           <tty>0</tty>
#           <total-run-time>586</total-run-time>
#           <invocation-count>20589</invocation-count>
#           <avg-run-time>28</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>3</pid>
#           <name>MCP TIPC</name>
#           <tty>0</tty>
#           <total-run-time>515</total-run-time>
#           <invocation-count>31654</invocation-count>
#           <avg-run-time>16</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>4</pid>
#           <name>Retransmission of IPC Versioning</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>5</pid>
#           <name>IPC ISSU Dispatch Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>6</pid>
#           <name>RF Slave Main Thread</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>12</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>7</pid>
#           <name>EDDRI_MAIN</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>8</pid>
#           <name>RO Notify Timers</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>9</pid>
#           <name>Check heaps</name>
#           <tty>0</tty>
#           <total-run-time>12108</total-run-time>
#           <invocation-count>13932</invocation-count>
#           <avg-run-time>869</avg-run-time>
#           <five-seconds>0.07</five-seconds>
#           <one-minute>0.01</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>10</pid>
#           <name>Pool Manager</name>
#           <tty>0</tty>
#           <total-run-time>88</total-run-time>
#           <invocation-count>1717</invocation-count>
#           <avg-run-time>51</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>11</pid>
#           <name>DiscardQ Background Mgr</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>12</pid>
#           <name>Timers</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>13</pid>
#           <name>WATCH_AFS</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>233</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>14</pid>
#           <name>IOSXE heartbeat process</name>
#           <tty>0</tty>
#           <total-run-time>139</total-run-time>
#           <invocation-count>51467</invocation-count>
#           <avg-run-time>2</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>15</pid>
#           <name>DB Lock Manager lock request process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>16</pid>
#           <name>DB Notification Manager process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>17</pid>
#           <name>ONEP Application</name>
#           <tty>0</tty>
#           <total-run-time>22</total-run-time>
#           <invocation-count>1863</invocation-count>
#           <avg-run-time>11</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>18</pid>
#           <name>VACS Background</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>19</pid>
#           <name>ATM AutoVC Periodic</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>20</pid>
#           <name>ATM VC Auto Creation Task</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>21</pid>
#           <name>IPC Apps Task</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>22</pid>
#           <name>ifIndex Receive Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>23</pid>
#           <name>IPC Event Notifier</name>
#           <tty>0</tty>
#           <total-run-time>36</total-run-time>
#           <invocation-count>20589</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>24</pid>
#           <name>IPC Mcast Pending Group Action</name>
#           <tty>0</tty>
#           <total-run-time>253</total-run-time>
#           <invocation-count>100508</invocation-count>
#           <avg-run-time>2</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>25</pid>
#           <name>Platform appsess Echo Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>26</pid>
#           <name>IPC Dynamic Cache</name>
#           <tty>0</tty>
#           <total-run-time>2</total-run-time>
#           <invocation-count>1716</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>27</pid>
#           <name>IPC Service NonConf Sess</name>
#           <tty>0</tty>
#           <total-run-time>3</total-run-time>
#           <invocation-count>20589</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>28</pid>
#           <name>IPC Zone Manager</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>29</pid>
#           <name>IPC Periodic Timer</name>
#           <tty>0</tty>
#           <total-run-time>119</total-run-time>
#           <invocation-count>100508</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>30</pid>
#           <name>IPC Deferred Port Closure</name>
#           <tty>0</tty>
#           <total-run-time>39</total-run-time>
#           <invocation-count>100508</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>31</pid>
#           <name>IPC Process level sends</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>32</pid>
#           <name>IPC Seat Manager</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>33</pid>
#           <name>IPC Check Queue Time Process</name>
#           <tty>0</tty>
#           <total-run-time>8</total-run-time>
#           <invocation-count>5883</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>34</pid>
#           <name>IPC Seat RX Controller</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>35</pid>
#           <name>IPC Seat TX Controller</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>36</pid>
#           <name>IPC Keep Alive Messages</name>
#           <tty>0</tty>
#           <total-run-time>70</total-run-time>
#           <invocation-count>10295</invocation-count>
#           <avg-run-time>6</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>37</pid>
#           <name>IPC Loadometer</name>
#           <tty>0</tty>
#           <total-run-time>130</total-run-time>
#           <invocation-count>20589</invocation-count>
#           <avg-run-time>6</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>38</pid>
#           <name>IPC Session Details</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>39</pid>
#           <name>SENSOR-MGR event process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>40</pid>
#           <name>ARP Input</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>14</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>41</pid>
#           <name>ARP Background</name>
#           <tty>0</tty>
#           <total-run-time>214</total-run-time>
#           <invocation-count>107378</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>42</pid>
#           <name>ATM Idle Timer</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>43</pid>
#           <name>ATM ASYNC PROC</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>44</pid>
#           <name>CEF MIB API</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>45</pid>
#           <name>DDR Timers</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>46</pid>
#           <name>Entity MIB API</name>
#           <tty>0</tty>
#           <total-run-time>1</total-run-time>
#           <invocation-count>4</invocation-count>
#           <avg-run-time>250</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>47</pid>
#           <name>PrstVbl</name>
#           <tty>0</tty>
#           <total-run-time>22</total-run-time>
#           <invocation-count>11</invocation-count>
#           <avg-run-time>2000</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>48</pid>
#           <name>Serial Background</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>49</pid>
#           <name>RMI RM Notify Watched Policy</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>50</pid>
#           <name>MEMLEAK PROCESS</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>51</pid>
#           <name>AAA_SERVER_DEADTIME</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>52</pid>
#           <name>Policy Manager</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>53</pid>
#           <name>IOSXE signals IOS cmd process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>54</pid>
#           <name>GraphIt</name>
#           <tty>0</tty>
#           <total-run-time>97</total-run-time>
#           <invocation-count>102941</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>55</pid>
#           <name>License IPC static worker</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>56</pid>
#           <name>License IPC server</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>57</pid>
#           <name>Net Input</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>58</pid>
#           <name>client_entity_sending_process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>59</pid>
#           <name>RF SCTPthread</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>60</pid>
#           <name>Dialer event</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>61</pid>
#           <name>SERIAL A'detect</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>62</pid>
#           <name>XML Proxy Client</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>63</pid>
#           <name>crypto sw pk proc</name>
#           <tty>0</tty>
#           <total-run-time>12</total-run-time>
#           <invocation-count>55</invocation-count>
#           <avg-run-time>218</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>64</pid>
#           <name>License Client Notification</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>3</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>65</pid>
#           <name>Licensing Auto Update Process</name>
#           <tty>0</tty>
#           <total-run-time>91</total-run-time>
#           <invocation-count>1717</invocation-count>
#           <avg-run-time>52</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>66</pid>
#           <name>License HA Consistency Checker Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>67</pid>
#           <name>Image License broker events process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>68</pid>
#           <name>Token Daemon</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>69</pid>
#           <name>Critical Bkgnd</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>70</pid>
#           <name>Net Background</name>
#           <tty>0</tty>
#           <total-run-time>294</total-run-time>
#           <invocation-count>66679</invocation-count>
#           <avg-run-time>4</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>71</pid>
#           <name>IDB Work</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>3</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>72</pid>
#           <name>Logger</name>
#           <tty>0</tty>
#           <total-run-time>1</total-run-time>
#           <invocation-count>58</invocation-count>
#           <avg-run-time>17</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>73</pid>
#           <name>TTY Background</name>
#           <tty>0</tty>
#           <total-run-time>311</total-run-time>
#           <invocation-count>102912</invocation-count>
#           <avg-run-time>3</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>74</pid>
#           <name>CTS CORE</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>3</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>75</pid>
#           <name>WSMA_NOTIFY</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>76</pid>
#           <name>SXP CORE</name>
#           <tty>0</tty>
#           <total-run-time>1</total-run-time>
#           <invocation-count>19</invocation-count>
#           <avg-run-time>52</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>77</pid>
#           <name>IOSD ipc task</name>
#           <tty>0</tty>
#           <total-run-time>3359</total-run-time>
#           <invocation-count>106166</invocation-count>
#           <avg-run-time>31</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>78</pid>
#           <name>IOSD chasfs task</name>
#           <tty>0</tty>
#           <total-run-time>16</total-run-time>
#           <invocation-count>20679</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>79</pid>
#           <name>Crimson flush transactions Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>80</pid>
#           <name>Cloud HA</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>81</pid>
#           <name>REDUNDANCY FSM</name>
#           <tty>0</tty>
#           <total-run-time>25</total-run-time>
#           <invocation-count>14707</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>82</pid>
#           <name>Punt FP Stats Dump Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>83</pid>
#           <name>PuntInject Keepalive Process</name>
#           <tty>0</tty>
#           <total-run-time>681</total-run-time>
#           <invocation-count>51449</invocation-count>
#           <avg-run-time>13</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>84</pid>
#           <name>IF-MGR control process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>4</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>85</pid>
#           <name>IF-MGR event process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>9</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>86</pid>
#           <name>SBC IPC Hold Queue Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>87</pid>
#           <name>CTS HA</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>88</pid>
#           <name>CTS HA IPC flow control</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>89</pid>
#           <name>Environmental Monitoring</name>
#           <tty>0</tty>
#           <total-run-time>135</total-run-time>
#           <invocation-count>102920</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>90</pid>
#           <name>RP HA Periodic</name>
#           <tty>0</tty>
#           <total-run-time>131</total-run-time>
#           <invocation-count>102920</invocation-count>
#           <avg-run-time>1</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>91</pid>
#           <name>cpf_msg_holdq_process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>92</pid>
#           <name>cpf_msg_rcvq_process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>93</pid>
#           <name>cpf_process_tpQ</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>94</pid>
#           <name>CONSOLE helper process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>95</pid>
#           <name>DBAL EVENTS</name>
#           <tty>0</tty>
#           <total-run-time>164</total-run-time>
#           <invocation-count>3464</invocation-count>
#           <avg-run-time>47</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>96</pid>
#           <name>CEF RRP RF waiter</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>97</pid>
#           <name>REDUNDANCY peer monitor</name>
#           <tty>0</tty>
#           <total-run-time>339</total-run-time>
#           <invocation-count>102921</invocation-count>
#           <avg-run-time>3</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>98</pid>
#           <name>100ms check</name>
#           <tty>0</tty>
#           <total-run-time>3361</total-run-time>
#           <invocation-count>1029434</invocation-count>
#           <avg-run-time>3</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>99</pid>
#           <name>ANCP HA</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>4</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>100</pid>
#           <name>ANCP HA IPC flow control</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>101</pid>
#           <name>QoS HA ID RETAIN</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>102</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>103</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>104</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>105</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>106</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>107</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>108</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>109</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>110</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>111</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>112</pid>
#           <name>CHKPT Test client process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>113</pid>
#           <name>Network-rf Notify Nego Done</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>114</pid>
#           <name>ARP HA</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>3</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>115</pid>
#           <name>XDR RRP RF waiter</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>116</pid>
#           <name>IOSXE-RP Punt Service Process</name>
#           <tty>0</tty>
#           <total-run-time>24</total-run-time>
#           <invocation-count>2006</invocation-count>
#           <avg-run-time>11</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>117</pid>
#           <name>IOSXE-RP Punt IPV6 Service Process</name>
#           <tty>0</tty>
# ...
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>574</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>575</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>576</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>577</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>578</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>579</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>580</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>581</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>582</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>583</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>584</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>585</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>586</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>587</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>588</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>589</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>590</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>591</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>592</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>593</pid>
#           <name>IPC ISSU Versioning Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>594</pid>
#           <name>CWAN OIR IPC Ready Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>595</pid>
#           <name>mdns Timer Process</name>
#           <tty>0</tty>
#           <total-run-time>57</total-run-time>
#           <invocation-count>6283</invocation-count>
#           <avg-run-time>9</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>596</pid>
#           <name>SBC main process</name>
#           <tty>0</tty>
#           <total-run-time>795</total-run-time>
#           <invocation-count>205810</invocation-count>
#           <avg-run-time>3</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>597</pid>
#           <name>MRIB Process</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>2</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>598</pid>
#           <name>EEM Helper Thread</name>
#           <tty>0</tty>
#           <total-run-time>8</total-run-time>
#           <invocation-count>483</invocation-count>
#           <avg-run-time>16</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>599</pid>
#           <name>ONEP Dispatch pool thread</name>
#           <tty>0</tty>
#           <total-run-time>99</total-run-time>
#           <invocation-count>3958</invocation-count>
#           <avg-run-time>25</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>600</pid>
#           <name>SBC Msg Ack Timer</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>602</pid>
#           <name>ONEP Dispatch pool thread</name>
#           <tty>0</tty>
#           <total-run-time>94</total-run-time>
#           <invocation-count>3957</invocation-count>
#           <avg-run-time>23</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>603</pid>
#           <name>ONEP Dispatch pool thread</name>
#           <tty>0</tty>
#           <total-run-time>79</total-run-time>
#           <invocation-count>3959</invocation-count>
#           <avg-run-time>19</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>604</pid>
#           <name>ONEP Dispatch pool thread</name>
#           <tty>0</tty>
#           <total-run-time>88</total-run-time>
#           <invocation-count>3959</invocation-count>
#           <avg-run-time>22</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>605</pid>
#           <name>ONEP Dispatch pool thread</name>
#           <tty>0</tty>
#           <total-run-time>100</total-run-time>
#           <invocation-count>3958</invocation-count>
#           <avg-run-time>25</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>606</pid>
#           <name>ONEP Dispatch XDM main</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>607</pid>
#           <name>XOS async sync XDM thread</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>4</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>608</pid>
#           <name>ONEP Network Element Process </name>
#           <tty>0</tty>
#           <total-run-time>2609</total-run-time>
#           <invocation-count>514090</invocation-count>
#           <avg-run-time>5</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>609</pid>
#           <name>CISCO_IA UPDATE</name>
#           <tty>0</tty>
#           <total-run-time>63</total-run-time>
#           <invocation-count>3432</invocation-count>
#           <avg-run-time>18</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>610</pid>
#           <name>DHCP Client</name>
#           <tty>0</tty>
#           <total-run-time>327</total-run-time>
#           <invocation-count>102922</invocation-count>
#           <avg-run-time>3</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>614</pid>
#           <name>Inter Chassis Protocol Manager</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#         <cpu-usage-process>
#           <pid>616</pid>
#           <name>LICENSE AGENT</name>
#           <tty>0</tty>
#           <total-run-time>0</total-run-time>
#           <invocation-count>1</invocation-count>
#           <avg-run-time>0</avg-run-time>
#           <five-seconds>0.0</five-seconds>
#           <one-minute>0.0</one-minute>
#           <five-minutes>0.0</five-minutes>
#         </cpu-usage-process>
#       </cpu-usage-processes>
#     </cpu-utilization>
#   </cpu-usage>
# </data>

# %%
memory_filter = '''
<filter>
  <memory-usage-processes xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-process-memory-oper"/>
</filter>
  '''
try:
    print ('Here we are printing process memory usage as XML\n')
    c = m.get(memory_filter)
    print(etree.tostring(c.data, pretty_print=True))
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("ERORR severity={}, tag={}".format(e.severity, e.tag))
# Out:
# Here we are printing process memory usage as XML
#
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <memory-usage-processes xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-process-memory-oper">
#     <memory-usage-process>
#       <pid>1</pid>
#       <name>Chunk Manager</name>
#       <tty>0</tty>
#       <allocated-memory>937496</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>967440</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>2</pid>
#       <name>Load Meter</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>17944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>3</pid>
#       <name>MCP TIPC</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>4</pid>
#       <name>Retransmission of IPC Versioning</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>5</pid>
#       <name>IPC ISSU Dispatch Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>6</pid>
#       <name>RF Slave Main Thread</name>
#       <tty>0</tty>
#       <allocated-memory>449744</allocated-memory>
#       <freed-memory>23672</freed-memory>
#       <holding-memory>397216</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>7</pid>
#       <name>EDDRI_MAIN</name>
#       <tty>0</tty>
#       <allocated-memory>65632</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>167576</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>8</pid>
#       <name>RO Notify Timers</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>9</pid>
#       <name>Check heaps</name>
#       <tty>0</tty>
#       <allocated-memory>6240</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>35736</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>10</pid>
#       <name>Pool Manager</name>
#       <tty>0</tty>
#       <allocated-memory>118926464</allocated-memory>
#       <freed-memory>118979096</freed-memory>
#       <holding-memory>215400</holding-memory>
#       <get-buffers>51</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>11</pid>
#       <name>DiscardQ Background Mgr</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>12</pid>
#       <name>Timers</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>13</pid>
#       <name>WATCH_AFS</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>17944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>14</pid>
#       <name>IOSXE heartbeat process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>15</pid>
#       <name>DB Lock Manager lock request process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>16</pid>
#       <name>DB Notification Manager process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>17</pid>
#       <name>ONEP Application</name>
#       <tty>0</tty>
#       <allocated-memory>1844000</allocated-memory>
#       <freed-memory>1343744</freed-memory>
#       <holding-memory>717104</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>18</pid>
#       <name>VACS Background</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>19</pid>
#       <name>ATM AutoVC Periodic</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>20</pid>
#       <name>ATM VC Auto Creation Task</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>21</pid>
#       <name>IPC Apps Task</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>22</pid>
#       <name>ifIndex Receive Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>23</pid>
#       <name>IPC Event Notifier</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>24</pid>
#       <name>IPC Mcast Pending Group Action</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>25</pid>
#       <name>Platform appsess Echo Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>26</pid>
#       <name>IPC Dynamic Cache</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>27</pid>
#       <name>IPC Service NonConf Sess</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>28</pid>
#       <name>IPC Zone Manager</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>29</pid>
#       <name>IPC Periodic Timer</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>30</pid>
#       <name>IPC Deferred Port Closure</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>31</pid>
#       <name>IPC Process level sends</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>32</pid>
#       <name>IPC Seat Manager</name>
#       <tty>0</tty>
#       <allocated-memory>2192</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>32136</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>33</pid>
#       <name>IPC Check Queue Time Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>34</pid>
#       <name>IPC Seat RX Controller</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>35</pid>
#       <name>IPC Seat TX Controller</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>36</pid>
#       <name>IPC Keep Alive Messages</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>37</pid>
#       <name>IPC Loadometer</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>38</pid>
#       <name>IPC Session Details</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>39</pid>
#       <name>SENSOR-MGR event process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>40</pid>
#       <name>ARP Input</name>
#       <tty>0</tty>
#       <allocated-memory>35824</allocated-memory>
#       <freed-memory>2960</freed-memory>
#       <holding-memory>62808</holding-memory>
#       <get-buffers>13</get-buffers>
#       <ret-buffers>13</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>41</pid>
#       <name>ARP Background</name>
#       <tty>0</tty>
#       <allocated-memory>4800</allocated-memory>
#       <freed-memory>4800</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>9</get-buffers>
#       <ret-buffers>9</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>42</pid>
#       <name>ATM Idle Timer</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>43</pid>
#       <name>ATM ASYNC PROC</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>44</pid>
#       <name>CEF MIB API</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>45</pid>
#       <name>DDR Timers</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>46</pid>
#       <name>Entity MIB API</name>
#       <tty>0</tty>
#       <allocated-memory>13944</allocated-memory>
#       <freed-memory>3800</freed-memory>
#       <holding-memory>40088</holding-memory>
#       <get-buffers>21</get-buffers>
#       <ret-buffers>21</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>47</pid>
#       <name>PrstVbl</name>
#       <tty>0</tty>
#       <allocated-memory>4032</allocated-memory>
#       <freed-memory>4032</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>48</pid>
#       <name>Serial Background</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>49</pid>
#       <name>RMI RM Notify Watched Policy</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>17944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>50</pid>
#       <name>MEMLEAK PROCESS</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>51</pid>
#       <name>AAA_SERVER_DEADTIME</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>52</pid>
#       <name>Policy Manager</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>53</pid>
#       <name>IOSXE signals IOS cmd process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>54</pid>
#       <name>GraphIt</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>55</pid>
#       <name>License IPC static worker</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>56</pid>
#       <name>License IPC server</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>57</pid>
#       <name>Net Input</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>58</pid>
#       <name>client_entity_sending_process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>59</pid>
#       <name>RF SCTPthread</name>
#       <tty>0</tty>
#       <allocated-memory>3192</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>33136</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>60</pid>
#       <name>Dialer event</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>61</pid>
#       <name>SERIAL A'detect</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>62</pid>
#       <name>XML Proxy Client</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>63</pid>
#       <name>crypto sw pk proc</name>
#       <tty>0</tty>
#       <allocated-memory>546832</allocated-memory>
#       <freed-memory>654752</freed-memory>
#       <holding-memory>30808</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>64</pid>
#       <name>License Client Notification</name>
#       <tty>0</tty>
#       <allocated-memory>768</allocated-memory>
#       <freed-memory>2752</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>2</get-buffers>
#       <ret-buffers>2</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>65</pid>
#       <name>Licensing Auto Update Process</name>
#       <tty>0</tty>
#       <allocated-memory>434033808</allocated-memory>
#       <freed-memory>434033808</freed-memory>
#       <holding-memory>30056</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>66</pid>
#       <name>License HA Consistency Checker Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>67</pid>
#       <name>Image License broker events process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>68</pid>
#       <name>Token Daemon</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>69</pid>
#       <name>Critical Bkgnd</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>70</pid>
#       <name>Net Background</name>
#       <tty>0</tty>
#       <allocated-memory>174728</allocated-memory>
#       <freed-memory>9280</freed-memory>
#       <holding-memory>58584</holding-memory>
#       <get-buffers>80</get-buffers>
#       <ret-buffers>80</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>71</pid>
#       <name>IDB Work</name>
#       <tty>0</tty>
#       <allocated-memory>3120</allocated-memory>
#       <freed-memory>2624</freed-memory>
#       <holding-memory>54440</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>72</pid>
#       <name>Logger</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>229</get-buffers>
#       <ret-buffers>229</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>73</pid>
#       <name>TTY Background</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>1896</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>74</pid>
#       <name>CTS CORE</name>
#       <tty>0</tty>
#       <allocated-memory>2400</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>56344</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>75</pid>
#       <name>WSMA_NOTIFY</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>102304</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>76</pid>
#       <name>SXP CORE</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>5384</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>77</pid>
#       <name>IOSD ipc task</name>
#       <tty>0</tty>
#       <allocated-memory>10390216</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>7133112</holding-memory>
#       <get-buffers>363</get-buffers>
#       <ret-buffers>363</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>78</pid>
#       <name>IOSD chasfs task</name>
#       <tty>0</tty>
#       <allocated-memory>13704</allocated-memory>
#       <freed-memory>13704</freed-memory>
#       <holding-memory>101944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>79</pid>
#       <name>Crimson flush transactions Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>80</pid>
#       <name>Cloud HA</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>81</pid>
#       <name>REDUNDANCY FSM</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>82</pid>
#       <name>Punt FP Stats Dump Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>83</pid>
#       <name>PuntInject Keepalive Process</name>
#       <tty>0</tty>
#       <allocated-memory>560</allocated-memory>
#       <freed-memory>560</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>51449</get-buffers>
#       <ret-buffers>51449</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>84</pid>
#       <name>IF-MGR control process</name>
#       <tty>0</tty>
#       <allocated-memory>1152</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>31096</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>85</pid>
#       <name>IF-MGR event process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>86</pid>
#       <name>SBC IPC Hold Queue Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>87</pid>
#       <name>CTS HA</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>88</pid>
#       <name>CTS HA IPC flow control</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>89</pid>
#       <name>Environmental Monitoring</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>90</pid>
#       <name>RP HA Periodic</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>91</pid>
#       <name>cpf_msg_holdq_process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>92</pid>
#       <name>cpf_msg_rcvq_process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>93</pid>
#       <name>cpf_process_tpQ</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>94</pid>
#       <name>CONSOLE helper process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>95</pid>
#       <name>DBAL EVENTS</name>
#       <tty>0</tty>
#       <allocated-memory>1088</allocated-memory>
#       <freed-memory>152</freed-memory>
#       <holding-memory>102880</holding-memory>
#       <get-buffers>19244</get-buffers>
#       <ret-buffers>19244</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>96</pid>
#       <name>CEF RRP RF waiter</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>17944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>97</pid>
#       <name>REDUNDANCY peer monitor</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>98</pid>
#       <name>100ms check</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>99</pid>
#       <name>ANCP HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>100</pid>
#       <name>ANCP HA IPC flow control</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>101</pid>
#       <name>QoS HA ID RETAIN</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>102</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>103</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>104</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>105</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>106</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>10096</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>40040</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>107</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>108</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>109</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>110</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>111</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>112</pid>
#       <name>CHKPT Test client process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>113</pid>
#       <name>Network-rf Notify Nego Done</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>114</pid>
#       <name>ARP HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>115</pid>
#       <name>XDR RRP RF waiter</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>17944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>116</pid>
#       <name>IOSXE-RP Punt Service Process</name>
#       <tty>0</tty>
#       <allocated-memory>59616</allocated-memory>
#       <freed-memory>23328</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>2361</get-buffers>
#       <ret-buffers>2361</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>117</pid>
#       <name>IOSXE-RP Punt IPV6 Service Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>118</pid>
#       <name>ACL Log Punt Service Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>119</pid>
#       <name>ACL deny punt service process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>120</pid>
#       <name>IOSXE-RP QFP HA Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>121</pid>
#       <name>DHCPC HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>122</pid>
#       <name>DHCPD HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>123</pid>
#       <name>DHCPv6 Relay HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>124</pid>
#       <name>DHCPv6 Server HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>125</pid>
#       <name>SISF HA Process</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>126</pid>
#       <name>Crypto PKI-HA</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>127</pid>
#       <name>IKE HA Mgr</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>128</pid>
#       <name>IPSEC HA Mgr</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>129</pid>
#       <name>RF Master Main Thread</name>
#       <tty>0</tty>
#       <allocated-memory>36008</allocated-memory>
#       <freed-memory>57520</freed-memory>
#       <holding-memory>50352</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>130</pid>
#       <name>RF Master Status Thread</name>
#       <tty>0</tty>
#       <allocated-memory>3280</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>33224</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>131</pid>
#       <name>Compute load avgs</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>132</pid>
#       <name>Per-minute Jobs</name>
#       <tty>0</tty>
#       <allocated-memory>5616</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>35560</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>133</pid>
#       <name>Per-Second Jobs</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>41944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>134</pid>
#       <name>ONEP CLI Command Server</name>
#       <tty>1</tty>
#       <allocated-memory>3126408</allocated-memory>
#       <freed-memory>1478408</freed-memory>
#       <holding-memory>1663584</holding-memory>
#       <get-buffers>16</get-buffers>
#       <ret-buffers>16</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>135</pid>
#       <name>Transport Port Agent</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>136</pid>
#       <name>IOSXE-RP FastPath Message Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>137</pid>
#       <name>FPDB Timer Process</name>
#       <tty>0</tty>
#       <allocated-memory>3376</allocated-memory>
#       <freed-memory>3136</freed-memory>
#       <holding-memory>54184</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>138</pid>
#       <name>fanrp_l2fib</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>139</pid>
#       <name>FEC_Link_event_handler</name>
#       <tty>0</tty>
#       <allocated-memory>448</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>140</pid>
#       <name>BFD HW EVENT</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>141</pid>
#       <name>BFD IPV6 ADDR CHANGE</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>53944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>142</pid>
#       <name>EEM ED MAT</name>
#       <tty>0</tty>
#       <allocated-memory>14312</allocated-memory>
#       <freed-memory>5680</freed-memory>
#       <holding-memory>50576</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>143</pid>
#       <name>EEM ED ND</name>
#       <tty>0</tty>
#       <allocated-memory>16496</allocated-memory>
#       <freed-memory>34984</freed-memory>
#       <holding-memory>52760</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>144</pid>
#       <name>SSLVPN Register Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
# ...
#       <pid>565</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>566</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>567</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>568</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>569</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>570</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>571</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>10096</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>40040</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>572</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>573</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>574</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>575</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>576</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>577</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>578</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>579</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>580</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>581</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>582</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>583</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>584</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>585</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>586</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>587</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>588</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>589</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>590</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>591</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>592</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>593</pid>
#       <name>IPC ISSU Versioning Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>594</pid>
#       <name>CWAN OIR IPC Ready Process</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>595</pid>
#       <name>mdns Timer Process</name>
#       <tty>0</tty>
#       <allocated-memory>78735960</allocated-memory>
#       <freed-memory>78735816</freed-memory>
#       <holding-memory>54088</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>596</pid>
#       <name>SBC main process</name>
#       <tty>0</tty>
#       <allocated-memory>34430416</allocated-memory>
#       <freed-memory>51800</freed-memory>
#       <holding-memory>34754616</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>597</pid>
#       <name>MRIB Process</name>
#       <tty>0</tty>
#       <allocated-memory>167616</allocated-memory>
#       <freed-memory>448</freed-memory>
#       <holding-memory>221112</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>598</pid>
#       <name>EEM Helper Thread</name>
#       <tty>0</tty>
#       <allocated-memory>3178088</allocated-memory>
#       <freed-memory>9504</freed-memory>
#       <holding-memory>38472</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>599</pid>
#       <name>ONEP Dispatch pool thread</name>
#       <tty>0</tty>
#       <allocated-memory>2934600</allocated-memory>
#       <freed-memory>4586248</freed-memory>
#       <holding-memory>55664</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>600</pid>
#       <name>SBC Msg Ack Timer</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>602</pid>
#       <name>ONEP Dispatch pool thread</name>
#       <tty>0</tty>
#       <allocated-memory>2520416</allocated-memory>
#       <freed-memory>4173176</freed-memory>
#       <holding-memory>55312</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>603</pid>
#       <name>ONEP Dispatch pool thread</name>
#       <tty>0</tty>
#       <allocated-memory>2857632</allocated-memory>
#       <freed-memory>4563984</freed-memory>
#       <holding-memory>55216</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>604</pid>
#       <name>ONEP Dispatch pool thread</name>
#       <tty>0</tty>
#       <allocated-memory>2830440</allocated-memory>
#       <freed-memory>4482192</freed-memory>
#       <holding-memory>55216</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>605</pid>
#       <name>ONEP Dispatch pool thread</name>
#       <tty>0</tty>
#       <allocated-memory>2541040</allocated-memory>
#       <freed-memory>4189136</freed-memory>
#       <holding-memory>55272</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>606</pid>
#       <name>ONEP Dispatch XDM main</name>
#       <tty>0</tty>
#       <allocated-memory>4536</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>58480</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>607</pid>
#       <name>XOS async sync XDM thread</name>
#       <tty>0</tty>
#       <allocated-memory>13768</allocated-memory>
#       <freed-memory>2024</freed-memory>
#       <holding-memory>65688</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>608</pid>
#       <name>ONEP Network Element Process </name>
#       <tty>0</tty>
#       <allocated-memory>1001560</allocated-memory>
#       <freed-memory>16432</freed-memory>
#       <holding-memory>805104</holding-memory>
#       <get-buffers>18</get-buffers>
#       <ret-buffers>18</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>609</pid>
#       <name>CISCO_IA UPDATE</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>610</pid>
#       <name>DHCP Client</name>
#       <tty>0</tty>
#       <allocated-memory>3601360</allocated-memory>
#       <freed-memory>11536</freed-memory>
#       <holding-memory>3644872</holding-memory>
#       <get-buffers>19</get-buffers>
#       <ret-buffers>19</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>614</pid>
#       <name>Inter Chassis Protocol Manager</name>
#       <tty>0</tty>
#       <allocated-memory>0</allocated-memory>
#       <freed-memory>0</freed-memory>
#       <holding-memory>29944</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#     <memory-usage-process>
#       <pid>616</pid>
#       <name>LICENSE AGENT</name>
#       <tty>0</tty>
#       <allocated-memory>51232</allocated-memory>
#       <freed-memory>2640</freed-memory>
#       <holding-memory>153176</holding-memory>
#       <get-buffers>0</get-buffers>
#       <ret-buffers>0</ret-buffers>
#     </memory-usage-process>
#   </memory-usage-processes>
# </data>

# %%
env_filter = '''
<filter>
  <environment-sensors xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-environment-oper"/>
</filter>
  '''
try:
    print ('Here we are printing environment data as XML\n')
    c = m.get(env_filter)
    print(etree.tostring(c.data, pretty_print=True))
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("ERORR severity={}, tag={}".format(e.severity, e.tag))
# Out:
# Here we are printing environment data as XML
#
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0"/>

# %% [markdown]
# Now that is a lot of information to look through, maybe you are only interested in a few pieces of information per route.  We can apply an XPATH filter, or use the capabilities of the underlying XML library, which will filter down the data.

# %%
env_filter = '''
<filter>
  <environment-sensors xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-environment-oper"/>
</filter>
  '''
try:
    c = m.get(env_filter)
    ns = 'http://cisco.com/ns/yang/Cisco-IOS-XE-environment-oper'
    nsmap = dict(env=ns)
    temp_table=[]
    readings = c.data.xpath(".//env:environment-sensor[env:sensor-units='Celsius']", namespaces=nsmap)
    for i, sensor in enumerate(readings):
        name = sensor.find('./env:name', namespaces=nsmap).text
        reading = sensor.find('./env:current-reading', namespaces=nsmap).text
        temp_table.append({'name':name, 'temperature':reading})
    pp = pprint.PrettyPrinter(indent=2)
    pp.pprint(temp_table)  
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print(e)
# Out:
# []

# %% [markdown]
# That seems easier to work with, but what are the items we can request?  In this case we can look at the capabilties and the models advertised.

# %% [markdown]
# ## YANG Models
# The best way to describe a YANG model is to take a look at one.  We can leverage NETCONF protocol to learn the capabilities of a device to include the det of Modles and even download the model schema itself and take a look.  Notice there are 2 types of models, open and native.
#
# ![  ](images/model_stack.png)

# %%
from subprocess import Popen, PIPE, STDOUT
#SCHEMA_TO_GET = 'Cisco-IOS-XE-memory-oper'
#SCHEMA_TO_GET = 'Cisco-IOS-XE-process-cpu-oper'
#SCHEMA_TO_GET = 'Cisco-IOS-XE-process-memory-oper'
#SCHEMA_TO_GET = 'Cisco-IOS-XE-environment-oper'
#SCHEMA_TO_GET = 'Cisco-IOS-XE-bgp'
#SCHEMA_TO_GET = 'Cisco-IOS-XE-bgp-common-oper'
#SCHEMA_TO_GET = 'openconfig-interfaces'
#SCHEMA_TO_GET = 'openconfig-acl'
#SCHEMA_TO_GET = 'openconfig-rib-bgp'
#SCHEMA_TO_GET = 'openconfig-vlan'
#SCHEMA_TO_GET = 'openconfig-platform'
#SCHEMA_TO_GET = 'ietf-interfaces'
SCHEMA_TO_GET = 'ietf-routing'
print('We are connecting to the device and downloading the YANG Module')
print('Now we will do a "pyang -f tree of %s.yang"' % SCHEMA_TO_GET)
print('This structure is what data we can get (ro/rw) or set (rw)\n')
c = m.get_schema(SCHEMA_TO_GET)
p = Popen(['pyang', '-f', 'tree'], stdout=PIPE, stdin=PIPE, stderr=PIPE)
stdout_data = p.communicate(input=c.data)[0]
print(stdout_data)
# Out:
# We are connecting to the device and downloading the YANG Module
# Now we will do a "pyang -f tree of ietf-routing.yang"
# This structure is what data we can get (ro/rw) or set (rw)
#
# module: ietf-routing
#     +--ro routing-state
#     |  +--ro routing-instance* [name]
#     |     +--ro name                 string
#     |     +--ro type?                identityref
#     |     +--ro router-id?           yang:dotted-quad
#     |     +--ro interfaces
#     |     |  +--ro interface*   if:interface-state-ref
#     |     +--ro routing-protocols
#     |     |  +--ro routing-protocol* [type name]
#     |     |     +--ro type    identityref
#     |     |     +--ro name    string
#     |     +--ro ribs
#     |        +--ro rib* [name]
#     |           +--ro name              string
#     |           +--ro address-family    identityref
#     |           +--ro default-rib?      boolean {multiple-ribs}?
#     |           +--ro routes
#     |              +--ro route* [destination-prefix]
#     |                 +--ro route-preference?     route-preference
#     |                 +--ro destination-prefix    string
#     |                 +--ro metric?               uint32
#     |                 +--ro next-hop
#     |                 |  +--ro (next-hop-options)
#     |                 |     +--:(simple-next-hop)
#     |                 |     |  +--ro outgoing-interface?   string
#     |                 |     |  +--ro next-hop-address?     string
#     |                 |     +--:(special-next-hop)
#     |                 |        +--ro special-next-hop?     enumeration
#     |                 +--ro source-protocol       identityref
#     |                 +--ro active?               empty
#     |                 +--ro last-updated?         yang:date-and-time
#     |                 +--ro update-source?        string
#     +--rw routing
#        +--rw routing-instance* [name]
#           +--rw name                 string
#           +--rw type?                identityref
#           +--rw enabled?             boolean
#           +--rw router-id?           yang:dotted-quad
#           +--rw description?         string
#           +--rw interfaces
#           |  +--rw interface*   if:interface-ref
#           +--rw routing-protocols
#           |  +--rw routing-protocol* [type name]
#           |     +--rw type             identityref
#           |     +--rw name             string
#           |     +--rw description?     string
#           |     +--rw static-routes
#           +--rw ribs
#              +--rw rib* [name]
#                 +--rw name              string
#                 +--rw address-family?   identityref
#                 +--rw description?      string
#   augment /if:interfaces-state/if:interface:
#     +--ro routing-instance?   string
#
#   rpcs:
#     +---x fib-route
#        +---w input
#        |  +---w routing-instance-name    string
#        |  +---w destination-address
#        |     +---w address-family    identityref
#        +--ro output
#           +--ro route
#              +--ro address-family     identityref
#              +--ro next-hop
#              |  +--ro (next-hop-options)
#              |     +--:(simple-next-hop)
#              |     |  +--ro outgoing-interface?   string
#              |     |  +--ro next-hop-address?     string
#              |     +--:(special-next-hop)
#              |        +--ro special-next-hop?     enumeration
#              +--ro source-protocol    identityref
#              +--ro active?            empty
#              +--ro last-updated?      yang:date-and-time

# %% [markdown]
# Now that we know whats available, we can grab operational data for the device to give us some perspective of its state.  In the coming months this will instead be a telemetry stream that a client could register for vs a poll.  However, we can see the advantage of how we can manipulate the information
#
# ![](images/netconf_stack.png)

# %% [markdown]
# ## NETCONF Operational Data

# %%
cpu_util = '''<filter>
      <cpu-usage xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-process-cpu-oper">
        <cpu-utilization>
          <five-seconds/>
        </cpu-utilization>
      </cpu-usage>
</filter>'''

memory = '''<filter>
      <memory-statistics xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-memory-oper">
        <memory-statistic>
          <total-memory/>
          <used-memory/>
        </memory-statistic>
      </memory-statistics>
</filter>'''


temp = '''<filter>
      <environment-sensors xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-environment-oper">
        <environment-sensor>
          <name/>
          <current-reading/>
          <sensor-units/>
        </environment-sensor>
      </environment-sensors>
</filter>'''

platform = '''<filter>
      <components xmlns="http://openconfig.net/yang/platform">
        <component>
          <state>
            <name/>
            <type/>
            <description/>
            <version/>
            <serial-no/>
            <part-no/>
          </state>
        </component>
      </components>
</filter>'''

#response = str( m.get(cpu_util))
#response = str( m.get(memory))
#response = str( m.get(temp))
response = m.get(platform)

import lxml.etree as etree
print(etree.tostring(response.data, pretty_print=True))

# %%
import xmltodict
import jxmlease

print ('Or you can convert to Dictionary/List:\n')
# my_list = xmltodict.parse( str(response) )['rpc-reply']['data']['components']['component']
my_list = jxmlease.parse_etree( str(response) )['rpc-reply']['data']['components']['component']
pp = pprint.PrettyPrinter(indent=2)
# Iterate through response and If it has a serial number, save to a new list/dictionary called my_filtered_list
my_filtered_list = [dict(i['state']) for i in my_list if i['state']['serial-no'] is not None] 
pp.pprint(my_filtered_list)

# %% [markdown]
# With structured data you can easily select data that's interesting.

# %% [markdown]
# ## NETCONF Configuration Data

# %%
CONF_FILTER ='''<filter>
  <interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
    <interface></interface>
  </interfaces>
</filter>'''

m = ncclient.manager.connect(
    host=HOST,
    port=PORT_NC,
    hostkey_verify=False,
    username=USER,
    password=PASS,
    device_params={'name':"csr"})

print('\nHere is the XML data for IETF Interfaces Configuration:\n')
interfaces = m.get_config('running',CONF_FILTER)
print(etree.tostring(interfaces.data, pretty_print=True))
# Out:
# Here is the XML data for Interfaces Configuration:
#
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
#     <interface>
#       <name>GigabitEthernet1</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>false</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>false</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>false</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>Loopback100</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:softwareLoopback</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>172.16.1.1</ip>
#           <netmask>255.255.255.255</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#   </interfaces>
# </data>

# %% [markdown]
# # RESTCONF
#
# RESTCONF is relative of NETCONF, born from YANG.  It provides access to the same data, but over a REST-like interface.  This extends access to YANG data to just about anything.  It is not a replacement to NETCONF, but instead an extension of a subset of the capabilities to REST capable systems.

# %% [markdown]
# ![](images/restconf_stack.jpg)

# %%
import requests
import json

HOST = '127.0.0.1'
PORT = 2225
PROT = 'https'
USER = 'vagrant'
PASS = 'vagrant'

API_JSON = 'application/yang-data+json'
DATA_JSON = 'application/yang-data+json'

def url(method=''):
    '''return the proper URL given the global vars and the
    method parameter.
    '''
    return "{prot}://{host}:{port}/restconf/{method}".format(prot=PROT, host=HOST, method=method, port=PORT)

def pp(data):
    '''pretty print the Python object
    '''
    if isinstance(data, requests.models.Response):
        if not data.ok:
            print('{}: {}'.format(data.status_code, data.text))
            return None
        obj = data.json()
    else:
        obj = data
    print(json.dumps(obj, indent=2))
    return obj

# Setup a global session with proper username and password
session = requests.Session()
session.auth = (USER, PASS)
# we also set the default dictionary with our 'Accept' header
session.headers = {'accept': DATA_JSON, 'content-type': DATA_JSON}

# are we using HTTPS?
if 'https' in PROT:
    # dont' verify certificates
    session.verify = False
    # disable warnings in case we use HTTPS
    requests.packages.urllib3.disable_warnings()

# %%
# sample params for the request
params_config = {
    "content": "config",
}
params_oper = {
    "content": "nonconfig"
}

# %%
o = pp(session.get(url(), headers=dict(accept=API_JSON)))
# Out:
# {
#   "restconf": {
#     "operations": {},
#     "data": {},
#     "yang-library-version": "2016-06-21"
#   }
# }

# %%
o = pp(session.get(url('data/restconf-state'),
                   headers=dict(accept=API_JSON),
                   params=params_oper))
# Out:
# {
#   "ietf-restconf-monitoring:restconf-state": {
#     "capabilities": {
#       "capability": [
#         "urn:ietf:params:restconf:capability:defaults:1.0?basic-mode=explicit",
#         "urn:ietf:params:restconf:capability:depth:1.0",
#         "urn:ietf:params:restconf:capability:fields:1.0",
#         "urn:ietf:params:restconf:capability:with-defaults:1.0",
#         "http://tail-f.com/ns/restconf/collection/1.0",
#         "http://tail-f.com/ns/restconf/query-api/1.0"
#       ]
#     }
#   }
# }

# %%
o = pp(session.get(url('data/openconfig-interfaces:interfaces/interface=GigabitEthernet1'),
                   headers=dict(accept=API_JSON),
                   params=params_config))
# Out:
# {
#   "openconfig-interfaces:interface": {
#     "openconfig-if-ethernet:ethernet": {
#       "config": {
#         "auto-negotiate": true
#       }
#     },
#     "config": {
#       "enabled": true,
#       "type": "iana-if-type:ethernetCsmacd",
#       "name": "GigabitEthernet1"
#     },
#     "name": "GigabitEthernet1",
#     "subinterfaces": {
#       "subinterface": [
#         {
#           "index": 0,
#           "openconfig-if-ip:ipv6": {
#             "config": {
#               "enabled": false
#             }
#           },
#           "config": {
#             "index": 0,
#             "enabled": true,
#             "name": "GigabitEthernet1"
#           }
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# # YDK
# Now that we are all Python experts, let's take a different perspective.  Models are similar to Programming languages.  Containers are to Classes, Lists are to Lists, Leafs are to Objects or types.
#
# In a community effort we have "compiled" the YANG model in to Python code.  By importing a few libraries we can affect change on networking elements simply by manipulating code.  All you need to do to use is "pip install ydk" to install.
#
# ![](images/YDK.png)

# %%
from ydk.services import CRUDService
from ydk.providers import NetconfServiceProvider
from ydk.models.ietf import ietf_interfaces as intf
from ydk.models.ietf import iana_if_type as iftype

PORT = 830

# create NETCONF provider
provider = NetconfServiceProvider(address=HOST,
                                  port=PORT,
                                  username=USER,
                                  password=PASS)
# create CRUD service
crud = CRUDService()

# query object
q_i = intf.Interfaces()

# get stuff
intfs = crud.read(provider, q_i)

# %%
# print interface names and types
for i in intfs.interface:
    print('%s, %s, %s' % (i.name, i.type._meta_info().yang_name, i.description))

# %%
q_i = intf.InterfacesState()

# get stuff
intfs = crud.read(provider, q_i)
q_i = intf.InterfacesState()

# get stuff
intfs = crud.read(provider, q_i)
int_info=[(i.name, i.statistics.out_pkts, int(i.speed)/1000000, i.oper_status) for i in intfs.interface]
for thing in int_info: print(str(thing))

# %% [markdown]
# ## Create Software Loopback

# %%
# new interface
new_loopback = intf.Interfaces.Interface()

# create a new loopback
new_loopback.name = 'Loopback666'
new_loopback.type = iftype.SoftwareloopbackIdentity()
new_loopback.description = 'Created by DevNet2449'
res = crud.create(provider, new_loopback)

# %%
# get stuff
q_i = intf.Interfaces()
intfs = crud.read(provider, q_i)

for i in intfs.interface:
    print('%s, %s, %s' % (i.name, i.type._meta_info().yang_name, i.description))

# %% [markdown]
# ## Delete Software Loopback

# %%
# create CRUD service
crud = CRUDService()

# interface to delete
to_del = intf.Interfaces.Interface()

# create a new loopback
to_del.name = 'Loopback666'
res = crud.delete(provider, to_del)

# %%
# get stuff
intfs = crud.read(provider, q_i)

for i in intfs.interface:
    print('%s, %s, %s' % (i.name, i.type._meta_info().yang_name, i.description))
provider.close()

# %% [markdown]
# # Telemetry
#
# Here is a new option to gather data.  Why use SNMP, Syslog, Netflow, etc when you can gather Model based telemetry as simply as sending a request to the device?
#
# ![](images/telemetry.png)

# %%
LOCAL = '10.5.193.82'
CLIENT = '172.16.54.145'
HOST = 'RS1-A3850-1'
PORT = 830
USER = 'admin'
PASS = 'c1sco123'

# %%
import requests

headers = {'Content-Type': 'application/json',}
# Grab telemetry on CPU utilization
data = '{"xpath":"/process-cpu-ios-xe-oper:cpu-usage/cpu-utilization/five-seconds", "period": 1000, "incident_id": 1234}'
response = requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)
print response

# %%
# Grab telemetry on Free Memory
data = '{"xpath":"/memory-ios-xe-oper:memory-statistics/memory-statistic/free-memory","period": 1000, "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %%
# Grab telemetry on Free Memory
data = '{"xpath":"/memory-ios-xe-oper:memory-statistics/memory-statistic/used-memory","period": 1000, "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %%
# Grab telemetry on Input 
data = '{"xpath":"/if:interfaces-state/interface[name=&quot;GigabitEthernet1/1/1&quot;]/statistics/in-octets","period": 1000,  "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %%
# Grab telemetry on Output
data = '{"xpath":"/if:interfaces-state/interface[name=&quot;GigabitEthernet1/1/1&quot;]/statistics/out-octets","period": 1000,  "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %%
# Grab telemetry on Output
data = '{"xpath":"/environment-ios-xe-oper:environment-sensors/environment-sensor/current-reading","period": 1000,  "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %%
# Grab telemetry on ACL Hit
data = '{"xpath":"/oc-acl:acl/acl-sets/acl-set[name=&quot;VTY-ACL&quot;]acl-entries/acl-entry[sequence-id=&quot;5&quot;]/state/matched-packets","period": 1000,  "incident_id": 1234}'
requests.post('http://%s:8320/sendrpc'% (LOCAL), headers=headers, data=data)

# %% [markdown]
# Take a look at Your ELK Stack (that you built outside this Notebook.  You have...Useful Information!
#
# Telemetry Stack
# ![](images/telemetry_stack.png)
